# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("allScoresTest.csv",sep=";")

# %%
df
# Out:
#                 Data_type Decoder_type LM_type              model_ID  \
# 0          Tue_test_split       greedy    None  DanSpeechPrimary.pth
# 1          Tue_test_split       greedy    None  DanSpeechPrimary.pth
# 2          Tue_test_split       greedy    None  DanSpeechPrimary.pth
# 3          Tue_test_split       greedy    None  DanSpeechPrimary.pth
# 4          Tue_test_split       greedy    None  DanSpeechPrimary.pth
# ..                    ...          ...     ...                   ...
# 198  Tue_Noise_test_split       greedy    None  DanSpeechPrimary.pth
# 199  Tue_Noise_test_split       greedy    None  DanSpeechPrimary.pth
# 200  Tue_Noise_test_split       greedy    None  DanSpeechPrimary.pth
# 201  Tue_Noise_test_split       greedy    None  DanSpeechPrimary.pth
# 202  Tue_Noise_test_split       greedy    None  DanSpeechPrimary.pth
#
#                                              Reference       WER       CER  \
# ...

# %%
df[df.Model_id != "AblationClean_only_tempo_perturb"].to_csv("allScores.csv",index=False,sep=";")

# %%
pd.read_csv("allScores.csv",sep=";")
# Out:
#                      Time                Model_id  \
# 0    01/05/2020, 21:04:23  AblationNoise_Baseline
# 1    01/05/2020, 21:04:23  AblationNoise_Baseline
# 2    01/05/2020, 21:04:23  AblationNoise_Baseline
# 3    01/05/2020, 21:04:23  AblationNoise_Baseline
# 4    01/05/2020, 21:04:23  AblationNoise_Baseline
# ..                    ...                     ...
# 195  01/05/2020, 21:46:42  AblationNoise_Baseline
# 196  01/05/2020, 21:46:42  AblationNoise_Baseline
# 197  01/05/2020, 21:46:42  AblationNoise_Baseline
# 198  01/05/2020, 21:46:42  AblationNoise_Baseline
# 199  01/05/2020, 21:46:42  AblationNoise_Baseline
#
#                                              Reference       WER       CER  \
# 0    psykiske ændringer indtræder hos de fleste eft...  0.681818  0.320261
# 1    men samfundet er vel os alle sammen inklusive ...  0.454545  0.115942
# 2    forsøget skal forhindre det alt for store fraf...  0.333333  0.097222
# ...
